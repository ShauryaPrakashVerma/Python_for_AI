# %% [markdown]
# <a href="https://colab.research.google.com/github/ShauryaPrakashVerma/Python_for_AI/blob/main/NLTK_Stop_Words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Write a python program to remove stop words for a given passage from a text file using NLTK**

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.1)

# %%
import nltk

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
text= "I love {} the feel of wood curls flying off the lathe as I begin to shape the log in front of me. The sound of scraping changes based on the wetness of the wood, the speed at which the lathe is turning, and the type of cut I am making. The smell and feel of wet wood being turned are unique. The water is sprayed out as I cut through the different layers of wood. A log can turn into anything one's imagination can think of with the right set of hands-on tools. I have those hands and imagination. I use all of my senses and intuition to create a beautiful object. That is why I enjoy turning wood."

# %%
stop_words = set(stopwords.words('english'))
tokens = word_tokenize(text.lower())
print(stop_words)
# Out:
# {"we're", 'nor', 'they', 'have', 'me', 'once', "weren't", 'ours', 'up', 'weren', 'where', 'an', 'during', 've', "mustn't", "couldn't", 'against', 'don', 'here', 'aren', 'mustn', 'was', "you're", 'isn', 'by', "won't", 'doing', 'my', "you've", 'shouldn', 'until', 'she', "that'll", 'needn', 'with', "they're", 'been', 'under', 'from', 'haven', "wouldn't", "she's", 'will', 'other', 'and', 'herself', 'won', "mightn't", 'itself', 'now', 'few', 'doesn', "doesn't", 'why', "it's", 'the', "it'd", 'more', "i've", 'some', "they've", 'but', 'hadn', 'it', 'mightn', "should've", 'before', "hadn't", 'so', 'd', 'again', 'hasn', "isn't", 'no', 'is', 'couldn', 'hers', "we've", 'over', 'on', 'ourselves', "needn't", "he'd", 'do', 'we', 'such', 's', 'what', 'am', 'which', 'can', "aren't", "it'll", 'm', 'in', 'about', "shouldn't", "i'm", "i'll", 'above', 'has', 'themselves', "shan't", 'through', 'because', 'himself', 'those', 'while', 'be', "they'll", 'own', 'after', 'or', 'then', 'between', 'same', "they'd", 'should', 'at', 'him', "he'll", 'myself', "haven't", 'any', 'of', 'both', 'than', 'as', 'that', 'for', 'how', 'yourselves', 'when', 'off', 'these', 'out', "hasn't", 'had', 'wouldn', 'into', 'll', 'only', 'theirs', 'o', "i'd", 'just', 't', 'whom', 'her', 'there', 'further', "don't", 'yourself', 'ma', 'to', "we'll", 'this', "she'll", 'you', 'below', "he's", "she'd", 'too', 'each', 'shan', 'very', 'y', "didn't", 'are', "we'd", 'a', 're', 'if', 'not', "wasn't", 'their', "you'd", 'having', 'did', 'its', 'most', 'ain', 'them', 'he', 'does', 'our', 'yours', 'didn', "you'll", 'all', 'wasn', 'your', 'who', 'were', 'being', 'his', 'i', 'down'}

# %%
filtered = [word for word in tokens if word not in stop_words]

print("Original:", tokens)
print("Filtered:", filtered)
# Out:
# Original: ['i', 'love', '{', '}', 'the', 'feel', 'of', 'wood', 'curls', 'flying', 'off', 'the', 'lathe', 'as', 'i', 'begin', 'to', 'shape', 'the', 'log', 'in', 'front', 'of', 'me', '.', 'the', 'sound', 'of', 'scraping', 'changes', 'based', 'on', 'the', 'wetness', 'of', 'the', 'wood', ',', 'the', 'speed', 'at', 'which', 'the', 'lathe', 'is', 'turning', ',', 'and', 'the', 'type', 'of', 'cut', 'i', 'am', 'making', '.', 'the', 'smell', 'and', 'feel', 'of', 'wet', 'wood', 'being', 'turned', 'are', 'unique', '.', 'the', 'water', 'is', 'sprayed', 'out', 'as', 'i', 'cut', 'through', 'the', 'different', 'layers', 'of', 'wood', '.', 'a', 'log', 'can', 'turn', 'into', 'anything', 'one', "'s", 'imagination', 'can', 'think', 'of', 'with', 'the', 'right', 'set', 'of', 'hands-on', 'tools', '.', 'i', 'have', 'those', 'hands', 'and', 'imagination', '.', 'i', 'use', 'all', 'of', 'my', 'senses', 'and', 'intuition', 'to', 'create', 'a', 'beautiful', 'object', '.', 'that', 'is', 'why', 'i', 'enjoy', 'turning', 'wood', '.']
# Filtered: ['love', '{', '}', 'feel', 'wood', 'curls', 'flying', 'lathe', 'begin', 'shape', 'log', 'front', '.', 'sound', 'scraping', 'changes', 'based', 'wetness', 'wood', ',', 'speed', 'lathe', 'turning', ',', 'type', 'cut', 'making', '.', 'smell', 'feel', 'wet', 'wood', 'turned', 'unique', '.', 'water', 'sprayed', 'cut', 'different', 'layers', 'wood', '.', 'log', 'turn', 'anything', 'one', "'s", 'imagination', 'think', 'right', 'set', 'hands-on', 'tools', '.', 'hands', 'imagination', '.', 'use', 'senses', 'intuition', 'create', 'beautiful', 'object', '.', 'enjoy', 'turning', 'wood', '.']

# %%
# file_path = 'passage.txt'
# example = "I love the feel of wood curls flying off the lathe as I begin to shape the log in front of me. The sound of scraping changes based on the wetness of the wood, the speed at which the lathe is turning, and the type of cut I am making. The smell and feel of wet wood being turned are unique. The water is sprayed out as I cut through the different layers of wood. A log can turn into anything one's imagination can think of with the right set of hands-on tools. I have those hands and imagination. I use all of my senses and intuition to create a beautiful object. That is why I enjoy turning wood."
# with open(file_path, 'w') as file:
#     file.write(example)

# with open(file_path, 'r') as file:
#     passage = file.read()
