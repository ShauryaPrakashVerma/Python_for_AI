# %% [markdown]
# <a href="https://colab.research.google.com/github/ShauryaPrakashVerma/Python_for_AI/blob/main/Lemmitizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

# %%
from nltk.stem import WordNetLemmatizer

# %%
nltk.download(funkt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-441187829.py in <cell line: 0>()
# ----> 1 nltk.download(funkt)
#
# NameError: name 'funkt' is not defined

# %%
nltk.download(wordnet)
nltk.download(omw 1.4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2049793743.py in <cell line: 0>()
# ----> 1 nltk.download(wordnet)
#
# NameError: name 'wordnet' is not defined
