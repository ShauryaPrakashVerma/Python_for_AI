# %% [markdown]
# <a href="https://colab.research.google.com/github/ShauryaPrakashVerma/Python_for_AI/blob/main/Important_interview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Shallow Copy
import copy
a = [[1,2], [3,4]]

b = copy.copy(a)
c = copy.deepcopy(a)

# b =  [12,12,23,4]
# print(a)
# print(b)

c[0] = 10
print(a)
print(c)
# Out:
# [[1, 2], [3, 4]]
# [10, [3, 4]]

# %%
import copy

def add_item(data):
    new_data = copy.copy(data)
    new_data[0].append(999)
    return new_data

original = [[1, 2], [3, 4]]
modified = add_item(original)

print(original)
# Out:
# [[1, 2, 999], [3, 4]]

# %%
import copy

a = [[1, 2], [3, 4]]
b = copy.copy(a)

b[1][0] = 99

print(a)
# Out:
# [[1, 2], [99, 4]]

# %%
import copy

a = [[1], [2]]
b = copy.deepcopy(a)

print(a[0] is b[0])
# Out:
# False

# %%
a = [1, 2, 3]
b = a
b = [4, 5, 6]

print(a)
# Out:
# [1, 2, 3]

# %%
import copy

a = [[10, 20], [30, 40]]
b = copy.copy(a)

b[0] = [99, 100]

print(a)
# Out:
# [[10, 20], [30, 40]]

# %%
import copy

a = [[1, 2], [3, 4]]
b = copy.deepcopy(a)

a[0][0] = 50

print(b)
# Out:
# [[1, 2], [3, 4]]

# %%
import copy

def add_item(data):
    new_data = copy.copy(data)
    new_data[0].append(999)
    return new_data

original = [[1, 2], [3, 4]]
modified = add_item(original)

print(original)
# Out:
# [[1, 2, 999], [3, 4]]

# %%
a = [[1, 2], [3, 4]]
b = a[:]

b[0][1] = 77

print(a)
# Out:
# [[1, 77], [3, 4]]

# %%
l = [False]
if l:
  print("Y")
else:
  print("No")
# Out:
# Y

# %%
l = ['Shaurya',"Prakash",'Verma']
